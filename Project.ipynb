# %%
#Typical libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

#Real-time data from https://data.cityofnewyork.us/Public-Safety/NYPD-Motor-Vehicle-Collisions/h9gi-nx95/data
#Uploading the data from start date(5/7/2014 made public) to 11/16/18
df = pd.read_csv('NYPD_Motor_Vehicle_Collisions.csv')
df = df.drop(df[df['ZIP CODE'].isna()].index) #taking out rows without zip code input
#Categorizing by zip code; latitude, longitude, location is not needed)
df = df.drop(columns=['LATITUDE', 'LONGITUDE', 'LOCATION']) 
#unique key is also not needed...just a randomly generated key
df = df.drop(columns=['UNIQUE KEY']) 
df.head(20)
# Out:
# C:\Users\Maggie\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           DATE   TIME    BOROUGH ZIP CODE                    ON STREET NAME  \
# 0   11/16/2018   0:10  MANHATTAN    10010  5 AVENUE
# 2   11/16/2018   0:45   BROOKLYN    11211  BORINQUEN PLACE
# 3   11/16/2018   1:00      BRONX    10454  EAST 137 STREET
# 4   11/16/2018   1:00   BROOKLYN    11221  WILSON AVENUE
# 7   11/16/2018   2:50      BRONX    10451  EAST 149 STREET
# 9   11/16/2018   5:30     QUEENS    11417  ROCKAWAY BOULEVARD
# 10  11/16/2018   5:45  MANHATTAN    10128  EAST 88 STREET
# 12  11/16/2018   6:02   BROOKLYN    11206                               NaN
# 13  11/16/2018   6:10  MANHATTAN    10128  EAST 92 STREET
# 14  11/15/2018   0:00   BROOKLYN    11228                               NaN
# 15  11/15/2018   0:00     QUEENS    11004  LITTLE NECK PARKWAY
# 16  11/15/2018   0:00     QUEENS    11368                               NaN
# 17  11/15/2018   0:00     QUEENS    11375  QUEENS BOULEVARD
# 21  11/15/2018   0:00     QUEENS    11413  NORTH CONDUIT AVENUE
# 22  11/15/2018   0:17   BROOKLYN    11204  AVENUE O
# 25  11/15/2018  10:00   BROOKLYN    11230  AVENUE I
# 26  11/15/2018  10:00     QUEENS    11434  ROCKAWAY BOULEVARD
# 28  11/15/2018  10:00   BROOKLYN    11229                               NaN
# 29  11/15/2018  10:09     QUEENS    11374  BOOTH STREET
# 30  11/15/2018  10:10     QUEENS    11378                               NaN
#
#      CROSS STREET NAME                           OFF STREET NAME  \
# 0             BROADWAY                                       NaN
# 2     HAVEMEYER STREET                                       NaN
# 3        WILLOW AVENUE                                       NaN
# 4      PALMETTO STREET                                       NaN
# 7        GERARD AVENUE                                       NaN
# 9   CENTREVILLE AVENUE                                       NaN
# 10            2 AVENUE                                       NaN
# 12                 NaN  787       BROADWAY
# 13            2 AVENUE                                       NaN
# 14                 NaN  1421      71 STREET
# 15          260 STREET                                       NaN
# 16                 NaN  103-03    ROOSEVELT AVENUE
# 17           77 AVENUE                                       NaN
# 21           230 PLACE                                       NaN
# 22      WEST 11 STREET                                       NaN
# 25       EAST 8 STREET                                       NaN
# 26   FARMERS BOULEVARD                                       NaN
# 28                 NaN  1835      EAST 14 STREET
# 29            63 DRIVE                                       NaN
# 30                 NaN  48-85     MASPETH AVENUE
#
#     NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0                           0                         0
# 2                           4                         0
# 3                           0                         0
# 4                           0                         0
# 7                           0                         0
# 9                           1                         0
# 10                          0                         0
# 12                          0                         0
# 13                          0                         0
# 14                          0                         0
# 15                          0                         0
# 16                          0                         0
# 17                          0                         0
# 21                          1                         0
# 22                          0                         0
# 25                          0                         0
# 26                          0                         0
# 28                          1                         0
# 29                          0                         0
# 30                          0                         0
#
#     NUMBER OF PEDESTRIANS INJURED         ...          \
# 0                               0         ...
# 2                               0         ...
# 3                               0         ...
# 4                               0         ...
# 7                               0         ...
# 9                               1         ...
# 10                              0         ...
# 12                              0         ...
# 13                              0         ...
# 14                              0         ...
# 15                              0         ...
# 16                              0         ...
# 17                              0         ...
# 21                              0         ...
# 22                              0         ...
# 25                              0         ...
# 26                              0         ...
# 28                              1         ...
# 29                              0         ...
# 30                              0         ...
#
#      CONTRIBUTING FACTOR VEHICLE 1   CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      Unspecified                     Unspecified
# 2   Driver Inattention/Distraction  Driver Inattention/Distraction
# 3                Pavement Slippery                     Unspecified
# 4                Pavement Slippery                     Unspecified
# 7   Driver Inattention/Distraction                     Unspecified
# 9   Driver Inattention/Distraction                             NaN
# 10                     Unspecified                             NaN
# 12           Following Too Closely  Driver Inattention/Distraction
# 13           Following Too Closely                     Unspecified
# 14   Failure to Yield Right-of-Way             Alcohol Involvement
# 15                     Unspecified                     Unspecified
# 16  Passing or Lane Usage Improper                     Unspecified
# 17     Traffic Control Disregarded                     Unspecified
# 21               Pavement Slippery                             NaN
# 22                Backing Unsafely                     Unspecified
# 25   Failure to Yield Right-of-Way                     Unspecified
# 26  Driver Inattention/Distraction                             NaN
# 28                Backing Unsafely                             NaN
# 29   Failure to Yield Right-of-Way                     Unspecified
# 30                Backing Unsafely                     Unspecified
#
#     CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 7                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                    Unspecified                            NaN
# 15                            NaN                            NaN
# 16                            NaN                            NaN
# 17                    Unspecified                            NaN
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 28                            NaN                            NaN
# 29                            NaN                            NaN
# 30                            NaN                            NaN
#
#     CONTRIBUTING FACTOR VEHICLE 5                  VEHICLE TYPE CODE 1  \
# 0                             NaN  Station Wagon/Sport Utility Vehicle
# 2                             NaN                                 Taxi
# 3                             NaN                    Garbage or Refuse
# 4                             NaN  Station Wagon/Sport Utility Vehicle
# 7                             NaN                                 Taxi
# 9                             NaN                                  NaN
# 10                            NaN  Station Wagon/Sport Utility Vehicle
# 12                            NaN                    Garbage or Refuse
# 13                            NaN                                Sedan
# 14                            NaN                                Sedan
# 15                            NaN  Station Wagon/Sport Utility Vehicle
# 16                            NaN                                Sedan
# 17                            NaN                                Sedan
# 21                            NaN  Station Wagon/Sport Utility Vehicle
# 22                            NaN                                Sedan
# 25                            NaN                                Sedan
# 26                            NaN                                Sedan
# 28                            NaN                                Sedan
# 29                            NaN  Station Wagon/Sport Utility Vehicle
# 30                            NaN                 Tractor Truck Diesel
#
#                     VEHICLE TYPE CODE 2 VEHICLE TYPE CODE 3  \
# 0   Station Wagon/Sport Utility Vehicle                 NaN
# 2                                  Taxi                 NaN
# 3   Station Wagon/Sport Utility Vehicle                 NaN
# 4   Station Wagon/Sport Utility Vehicle                 NaN
# 7                                  Taxi                 NaN
# 9                                   NaN                 NaN
# 10                                  NaN                 NaN
# 12                                Sedan                 NaN
# 13                                Sedan                 NaN
# 14                                Sedan               Sedan
# 15                                Sedan                 NaN
# 16  Station Wagon/Sport Utility Vehicle                 NaN
# 17                                Sedan               Sedan
# 21                                  NaN                 NaN
# 22  Station Wagon/Sport Utility Vehicle                 NaN
# 25                                 Dump                 NaN
# 26                                  NaN                 NaN
# 28                                  NaN                 NaN
# 29                                Sedan                 NaN
# 30                               Tanker                 NaN
#
#    VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                  NaN                 NaN
# 2                  NaN                 NaN
# 3                  NaN                 NaN
# 4                  NaN                 NaN
# 7                  NaN                 NaN
# 9                  NaN                 NaN
# 10                 NaN                 NaN
# 12                 NaN                 NaN
# 13                 NaN                 NaN
# 14                 NaN                 NaN
# 15                 NaN                 NaN
# 16                 NaN                 NaN
# 17                 NaN                 NaN
# 21                 NaN                 NaN
# 22                 NaN                 NaN
# 25                 NaN                 NaN
# 26                 NaN                 NaN
# 28                 NaN                 NaN
# 29                 NaN                 NaN
# 30                 NaN                 NaN
#
# [20 rows x 25 columns]

# %%
nsamp, natt = df.shape
print('num samples = {0:d}, num attributes = {1:d}'.format(nsamp,natt))

#General visualization of zip codes
x_unfiltered = np.array(df['ZIP CODE'])
x_unfiltered = pd.Series(zipcode).dropna()
zipcode = x_unfiltered.astype(int) #casting to integer from float
#print(zipcode)

#number of accidents per zip code
naccidents = pd.Series(zipcode).value_counts().tolist()
#print(pd.Series(zipcode).value_counts())

plt.figure(figsize=(20,20))
plt.scatter(pd.Series(zipcode).value_counts().index.tolist(), pd.Series(zipcode).value_counts())
plt.xticks((np.arange(10000, 11750, 50)), rotation = 90)
plt.grid()
# Out:
# num samples = 978601, num attributes = 25

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Number of vehicles involved = # of entries filled in columns vehicle type code 1-5 for said accident

# %%
#Type of vehicles

# %%
#Cause of crash

# %%
#Time of occurance (day/night)

# %%
#All of above components per zipcode
